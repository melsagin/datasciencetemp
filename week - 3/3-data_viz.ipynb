# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib.patches as mpatches
import seaborn as sns
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({
    'Group': ['A', 'B', 'C', 'D', 'E'],
    'Value': [1, 5, 4, 3, 9]
})

# %%
plt.barh(y=df.Group, width=df.Value)
# Out:
# <BarContainer object of 5 artists>

# %%
df = df.sort_values(by=['Value'])
my_plot = plt.barh(
    y=df.Group,
    width=df.Value,
    color=mcolors.TABLEAU_COLORS,
    edgecolor='black',
    linewidth=3
    )
plt.bar_label(container=my_plot, padding=4)
plt.show()

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
"""
total_bill: Yemek için ödenen toplam tutar (dolar cinsinden)
tip: Bahşiş miktarı (dolar cinsinden)
sex: Cinsiyet (erkek veya kadın)
smoker: Sigara içen müşteri mi? (Yes veya No)
day: Haftanın günü (Thur, Fri, Sat, Sun)
time: Öğle (Lunch) veya akşam (Dinner) yemeği mi?
size: Grup büyüklüğü (kişi sayısı)
"""
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
sns.set(style="darkgrid")
sns.barplot(
    x="total_bill",
    y="day",
    data=tips,
)
plt.figure(figsize=(18, 8))

# %%
# Aslıhan's example
g = sns.FacetGrid(tips, col="day", height=4, aspect=.5)
g.map(sns.barplot, "sex", "total_bill", order=["Male", "Female"])

# %%
total = tips.groupby('day')['total_bill'].sum().reset_index()

# %%
total
# Out:
#     day  total_bill
# 0  Thur     1096.33
# 1   Fri      325.88
# 2   Sat     1778.40
# 3   Sun     1627.16

# %%
bar1 = sns.barplot(x="day",  y="total_bill", data=total, color='darkblue')

# %%
smoker = tips[tips.smoker=='Yes']

# %%
bar2 = sns.barplot(
    x='day',
    y='total_bill',
    data=smoker,
    estimator=sum,
    color='lightblue'
)

# %%
bar1 = sns.barplot(x="day",  y="total_bill", data=total, color='darkblue')
bar2 = sns.barplot(
    x='day',
    y='total_bill',
    data=smoker,
    estimator=sum,
    color='lightblue'
)
top_bar = mpatches.Patch(color='darkblue', label='non-smoker')
bottom_bar = mpatches.Patch(color='lightblue', label='smoker = Yes')
plt.legend(handles=[top_bar, bottom_bar])
plt.show()
