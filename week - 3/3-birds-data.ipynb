# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
base_url = "C:/Users/M E L S A/Desktop/M E L S A/data_science/datasciencetemp/data/birds/"
birds_dataset_url = base_url + "birds.csv"

# %%
df = pd.read_csv(birds_dataset_url) #url yi oku ve DataFrame objesine ata
df.head()
# Out:
#                            Name          ScientificName  \
# 0  Black-bellied whistling-duck  Dendrocygna autumnalis
# 1        Fulvous whistling-duck     Dendrocygna bicolor
# 2                    Snow goose      Anser caerulescens
# 3                  Ross's goose            Anser rossii
# 4   Greater white-fronted goose         Anser albifrons
#
#                 Category         Order    Family        Genus  \
# 0  Ducks/Geese/Waterfowl  Anseriformes  Anatidae  Dendrocygna
# 1  Ducks/Geese/Waterfowl  Anseriformes  Anatidae  Dendrocygna
# 2  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
# 3  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
# 4  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
#
#   ConservationStatus  MinLength  MaxLength  MinBodyMass  MaxBodyMass  \
# 0                 LC       47.0       56.0        652.0       1020.0
# 1                 LC       45.0       53.0        712.0       1050.0
# ...

# %%
df.tail()
# Out:
#                 Name      ScientificName          Category          Order  \
# 438    Blue grosbeak  Passerina caerulea  Cardinals/Allies  Passeriformes
# 439   Lazuli bunting    Passerina amoena  Cardinals/Allies  Passeriformes
# 440   Indigo bunting    Passerina cyanea  Cardinals/Allies  Passeriformes
# 441  Painted bunting     Passerina ciris  Cardinals/Allies  Passeriformes
# 442       Dickcissel     Spiza americana  Cardinals/Allies  Passeriformes
#
#            Family      Genus ConservationStatus  MinLength  MaxLength  \
# 438  Cardinalidae  Passerina                 LC       14.0       19.0
# 439  Cardinalidae  Passerina                 LC       13.0       15.0
# 440  Cardinalidae  Passerina                 LC       11.5       15.0
# 441  Cardinalidae  Passerina                 LC       12.0       14.0
# 442  Cardinalidae      Spiza                 LC       14.0       16.0
#
#      MinBodyMass  MaxBodyMass  MinWingspan  MaxWingspan
# ...

# %%
# En yüksek orana sahip satırı bul
max_ratio_row = oran_df.loc[oran_df['Oran'].idxmax()]

# Sonuçları yazdır
print("ScientificName:", max_ratio_row['ScientificName'])
print("Max Body Mass:", max_ratio_row['MaxBodyMass'])
print("Min Body Mass:", max_ratio_row['MinBodyMass'])
print("Max/Min Body Mass Ratio:", max_ratio_row['Oran'])
# Out:
# ScientificName: Anser caerulescens
# Max Body Mass: 4050.0
# Min Body Mass: 2050.0
# Max/Min Body Mass Ratio: 1.975609756097561

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443 entries, 0 to 442
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                443 non-null    object
#  1   ScientificName      443 non-null    object
#  2   Category            443 non-null    object
#  3   Order               443 non-null    object
#  4   Family              443 non-null    object
#  5   Genus               443 non-null    object
#  6   ConservationStatus  443 non-null    object
#  7   MinLength           443 non-null    float64
#  8   MaxLength           443 non-null    float64
#  9   MinBodyMass         443 non-null    float64
#  10  MaxBodyMass         443 non-null    float64
#  11  MinWingspan         443 non-null    float64
#  12  MaxWingspan         443 non-null    float64
#  13  Oran                443 non-null    float64
# dtypes: float64(7), object(7)
# memory usage: 48.6+ KB

# %%
df.describe()
# Out:
#         MinLength   MaxLength  MinBodyMass   MaxBodyMass  MinWingspan  \
# count  443.000000  443.000000   443.000000    443.000000   443.000000
# mean    28.536682   35.441986   327.938262    667.009752    58.557901
# std     20.319887   27.539772   779.680106   1655.682564   104.602369
# min      7.000000    8.900000     2.000000      3.000000     8.000000
# 25%     13.750000   16.000000    18.000000     28.000000    23.000000
# 50%     20.500000   25.000000    55.000000     89.000000    38.000000
# 75%     39.000000   46.000000   332.000000    593.000000    72.750000
# max    138.000000  180.000000  9200.000000  14300.000000  1800.000000
#
#        MaxWingspan        Oran
# count   443.000000  443.000000
# mean     67.524492    1.719967
# std     126.673177    0.634902
# min      10.600000    0.677419
# 25%      25.000000    1.295418
# 50%      42.000000    1.593220
# 75%      83.000000    1.982275
# max    2300.000000    6.000000

# %%
plt.scatter(df["MaxBodyMass"], df["MinBodyMass"], color="blue")
plt.title("İki Değişkenli Analiz için Scatter Plot")
plt.xlabel("Max Body Mass")
plt.ylabel("Min Body Mass")
plt.show()

# %%
df["MaxBodyMass"].corr(df["MinBodyMass"])
# Out:
# 0.9331662943874605

# %%
plt.hist(df["MaxLength"], bins = 20)
plt.title("Histogram")
plt.xlabel("MaxLength")
plt.ylabel("Frekans")
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.boxplot([df['MinLength'], df['MaxLength']])
plt.xticks([1, 2], ['MinLength', 'MaxLength'])
plt.title('Matplotlib Boxplot Örneği')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.boxplot([df['MinBodyMass'], df['MaxBodyMass']])
plt.xticks([1, 2], ['MinBodyMass', 'MaxBodyMass'])
plt.title('Matplotlib Boxplot Örneği')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.boxplot([ df['MinWingspan'], df['MaxWingspan']])
plt.xticks([1, 2], [ 'MinWingspan', 'MaxWingspan'])
plt.title('Matplotlib Boxplot Örneği')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Name', y='MaxBodyMass', data=df[:10], color='black', label='Max Body Mass')
sns.barplot(x='Name', y='MinBodyMass', data=df[:10], color='orange', label='Min Body Mass')
plt.title('MaxBodyMass ve MinBodyMass Karşılaştırma (Bar Plot)')
plt.xticks(rotation=45, ha='right')
plt.ylabel('BodyMass')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df[['MinLength', 'MaxLength', 'MinBodyMass', 'MaxBodyMass', 'MinWingspan', 'MaxWingspan']])
plt.title('Seaborn Boxplot Örneği')
plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.scatter(df['MinBodyMass'], df['MaxBodyMass'], label='BodyMass', color='orange')
plt.scatter(df['MinWingspan'], df['MaxWingspan'], label='Wingspan', color='green')
plt.scatter(df['MinLength'], df['MaxLength'], label='Length', color='blue')

plt.title('Scatter Plot Örneği')
plt.xlabel('Min Values')
plt.ylabel('Max Values')
plt.legend()
plt.grid(True)
plt.show()

# %%
#VKİ Hesaplama
df['BodyMassIndex'] =  df['MaxBodyMass']/((df['MaxLength']*df['MaxLength'])/10)

plt.figure(figsize=(10, 6))
plt.scatter(df['MaxBodyMass'], df['MaxLength'], c=df['BodyMassIndex'], cmap='viridis', s=100, edgecolors='black', linewidths=1, alpha=0.75)


cbar = plt.colorbar()
cbar.set_label('Body Mass Index')

plt.title('MaxWingspan vs MaxBodyMass Scatter Plot')
plt.xlabel('Max BodyMass')
plt.ylabel('Max Length')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x='MaxBodyMass', y='MaxWingspan', data=df)
plt.title('MaxBodyMass vs MaxWingspan (Scatter Plot)')
plt.xlabel('Max Body Mass')
plt.ylabel('Max Wingspan')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Name', y='MaxBodyMass', data=df, color='blue', label='Max BodyMass')
sns.barplot(x='Name', y='MinBodyMass', data=df, color='orange', label='Min BodyMass')
plt.title('MaxBodyMass ve MinBodyMass Karşılaştırma (Bar Plot)')
plt.xlabel('Species')
plt.ylabel('BodyMass')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.regplot(x='MaxLength', y='MaxBodyMass', data=df, scatter_kws={'s': 100}, ci=None)
plt.title('MaxLength ve MaxBodyMass Arasındaki İlişki (regplot)')
plt.xlabel('MaxLength')
plt.ylabel('MaxBodyMass')
plt.show()
