# %%
import pandas as pd
from sklearn.datasets import load_iris
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# pip3 install scikit-learn
# pip install scikit-learn

# %%
iris = load_iris()
iris_df = pd.DataFrame(data=iris['data'], columns=iris['feature_names'])

# %%
iris_df['species'] = iris['target_names'][iris['target']]

# %%
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   species            150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris_df.shape
# Out:
# (150, 4)

# %%
iris_df.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'species'],
#       dtype='object')

# %%
plt.scatter(iris_df["petal length (cm)"], iris_df["petal width (cm)"], color="blue")
plt.title("İki Değişkenli Analiz için Scatter Plot")
plt.xlabel("petal length")
plt.ylabel("petal width")
plt.show()

# %%
plt.hist(iris_df["sepal width (cm)"], bins = 20)
plt.title("Sepal Width için Histogram")
plt.xlabel("sepal width")
plt.ylabel("Frekans")
plt.show()

# %%
sns.barplot(iris_df["species"], iris_df["sepal length (cm)"])
plt.title("Barplot")
# Out:
# c:\Users\M E L S A\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Barplot')

# %%
labels = ["Setosa", "Versicolor", "Virginica"]
plt.pie(sizes, labels = labels)
plt.axis('equal')
plt.show()

# %%
iris_df.corr()
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.117570           0.871754
# sepal width (cm)           -0.117570          1.000000          -0.428440
# petal length (cm)           0.871754         -0.428440           1.000000
# petal width (cm)            0.817941         -0.366126           0.962865
#
#                    petal width (cm)
# sepal length (cm)          0.817941
# sepal width (cm)          -0.366126
# petal length (cm)          0.962865
# petal width (cm)           1.000000

# %%
sns.heatmap(iris_df.corr(), cmap = 'coolwarm', annot = True)
# bir ısı haritasında annot=True olarak ayarlanırsa, her hücre içine karşılık gelen değer yazılır. 
# cmap parametresi ise renk haritasını belirler.
# Out:
# <AxesSubplot:>

# %%
sns.displot(iris_df["sepal width (cm)"], bins = 25, kde = True)
# bins=25 ifadesi, veri setini 25 aralığa böler ve bu aralıklarda histogram çubukları oluşturur.
# Çekirdek Yoğunluk Tahminini (Kernel Density Estimate - KDE) gösterip göstermeme durumunu belirler. 
# True olarak ayarlanırsa, çekirdek yoğunluk tahminini gösterir. 
# Bu, veri setinin olasılık yoğunluğunu yumuşak bir şekilde görselleştirmeye yardımcı olur.

# %%
sns.regplot(
    iris_df["petal length (cm)"], 
    iris_df["petal width (cm)"],
    color = "blue",
    marker = "*",
    line_kws={
        "color": "red",
        "alpha": 0.6,
        "lw": 5
    }
    )
# Out:
# c:\Users\M E L S A\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='petal length (cm)', ylabel='petal width (cm)'>

# %%
sns.lmplot(
    x = "petal length (cm)", 
    y = "petal width (cm)",
    data = iris_df,
    hue = "species"
)

# %%
sns.boxplot(
    x = iris_df["species"], 
    y = iris_df["sepal length (cm)"],
)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal length (cm)'>

# %%
iris_df.boxplot(column='sepal length (cm)', by='species')
plt.show()
