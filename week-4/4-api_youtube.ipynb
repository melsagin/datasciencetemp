# %%
import pandas as pd

# %%
import requests
from config import YOUTUBE_API_KEY

# %% [markdown]
# #####
# - Aktif edilmesi gereken console: https://console.cloud.google.com/apis/library/youtube.googleapis.com?project=youtubeapi-408407
# - Youtube isminden CHANNEL_ID bulma: https://www.streamweasels.com/tools/youtube-channel-id-and-user-id-convertor/
# - Daha sonra kullanabileceğin örnek api'ler: https://github.com/public-apis/public-apis

# %%
CHANNEL_ID ="UC6OI7Crv96jgra5pwJNDFRQ"
pageToken = ""
url = "https://www.googleapis.com/youtube/v3/search?key="+YOUTUBE_API_KEY+"&channelId="+CHANNEL_ID+"&part=snippet,id&order=date&maxResults=1000"+pageToken

# %%
print(url)
# Out:
# https://www.googleapis.com/youtube/v3/search?key=AIzaSyDdu5WaUqfzXrS1vKfFXmSPiYbsRFZpt6o&channelId=UC6OI7Crv96jgra5pwJNDFRQ&part=snippet,id&order=date&maxResults=1000

# %%
response = requests.get(url).json()

# %%
response
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'Nux6tDq5UpOOms3P1_MdrZwcV0M',
#  'nextPageToken': 'CDIQAA',
#  'regionCode': 'TR',
#  'pageInfo': {'totalResults': 805, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': 'QsGPahY_L8jBpYCSPevqWvwE84E',
#    'id': {'kind': 'youtube#video', 'videoId': 'SwFG0k9ezHg'},
#    'snippet': {'publishedAt': '2023-12-03T17:00:17Z',
#     'channelId': 'UC6OI7Crv96jgra5pwJNDFRQ',
#     'title': 'Sezen Aksu - Gidiyorum #SezenAksu #MinikSerçe #gidiyorum #Shorts',
#     'description': 'Sezen Aksu Resmi YouTube Kanalına Abone Olun: https://goo.gl/xPnZlA ================================= Resmi Web ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/SwFG0k9ezHg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/SwFG0k9ezHg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/SwFG0k9ezHg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sezen Aksu',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-12-03T17:00:17Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '6zbKzYkc6nPSmsKLb2w8ukE69O4',
#    'id': {'kind': 'youtube#video', 'videoId': 'EF9NO-fvs3c'},
#    'snippet': {'publishedAt': '2023-11-29T15:30:08Z',
#     'channelId': 'UC6OI7Crv96jgra5pwJNDFRQ',
#     'title': 'Sezen Aksu - Keskin Bıçak #SezenAksu #MinikSerçe #keskinbıçak #Shorts',
#     'description': 'Sezen Aksu Resmi YouTube Kanalına Abone Olun: https://goo.gl/xPnZlA ================================= Resmi Web ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/EF9NO-fvs3c/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/EF9NO-fvs3c/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/EF9NO-fvs3c/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sezen Aksu',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-11-29T15:30:08Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'zszagDmk0kYaW4Bjf7g_kwhQNyw',
#    'id': {'kind': 'youtube#video', 'videoId': '_y08PXbalHg'},
#    'snippet': {'publishedAt': '2023-11-26T17:00:33Z',
#     'channelId': 'UC6OI7Crv96jgra5pwJNDFRQ',
#     'title': 'Sezen Aksu - Erkek Güzeli #SezenAksu #MinikSerçe #erkekgüzeli  #Shorts',
#     'description': 'Sezen Aksu Resmi YouTube Kanalına Abone Olun: https://goo.gl/xPnZlA ================================= Resmi Web ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/_y08PXbalHg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/_y08PXbalHg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/_y08PXbalHg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sezen Aksu',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-11-26T17:00:33Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'bAml30QGErhkS9NQiG1iYbAFm6A',
#    'id': {'kind': 'youtube#video', 'videoId': '7HNOJisHhbg'},
#    'snippet': {'publishedAt': '2023-11-03T08:00:06Z',
#     'channelId': 'UC6OI7Crv96jgra5pwJNDFRQ',
#     'title': 'Sezen Aksu - Yanıyom Ölüyom (Canlı Performans)',
#     'description': 'Ağustos, 1995 - Rumeli Hisarı Konseri Söz: Sezen Aksu Müzik: Sezen Aksu Şarkı Sözleri: Be kardeş şu köşeden Bir rakı al da gel ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/7HNOJisHhbg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/7HNOJisHhbg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/7HNOJisHhbg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sezen Aksu',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-11-03T08:00:06Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'BruoXVhcANhVBsF6wVeV_BysLI0',
#    'id': {'kind': 'youtube#video', 'videoId': 'EOADibxhQms'},
#    'snippet': {'publishedAt': '2023-10-28T17:00:10Z',
#     'channelId': 'UC6OI7Crv96jgra5pwJNDFRQ',
#     'title': 'Sezen Aksu - Değer mi? #SezenAksu #MinikSerçe #değermi  #Shorts',
#     'description': 'Sezen Aksu Resmi YouTube Kanalına Abone Olun: https://goo.gl/xPnZlA ================================= Resmi Web ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/EOADibxhQms/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/EOADibxhQms/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/EOADibxhQms/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sezen Aksu',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-10-28T17:00:10Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'XU8gJ9byr_jypJ-hFVyFF3idcjA',
#    'id': {'kind': 'youtube#video', 'videoId': 'nYUb6k9VB_o'},
#    'snippet': {'publishedAt': '2023-10-25T12:31:45Z',
#     'channelId': 'UC6OI7Crv96jgra5pwJNDFRQ',
#     'title': 'Sezen Aksu - Yanmışım Sönmüşüm Ben #SezenAksu #MinikSerçe #yanmışımsönmüşümben #Shorts',
#     'description': 'Sezen Aksu Resmi YouTube Kanalına Abone Olun: https://goo.gl/xPnZlA ================================= Resmi Web ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/nYUb6k9VB_o/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/nYUb6k9VB_o/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/nYUb6k9VB_o/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sezen Aksu',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-10-25T12:31:45Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'L7WkyZh6e2vAdKzlNgYZz4F02X0',
#    'id': {'kind': 'youtube#video', 'videoId': 'MsaGFWTQ9ug'},
#    'snippet': {'publishedAt': '2023-10-16T15:00:26Z',
#     'channelId': 'UC6OI7Crv96jgra5pwJNDFRQ',
#     'title': 'Sezen Aksu - Rahatı Kaçan Ağaç #SezenAksu #MinikSerçe #rahatıkaçanağaç #Shorts',
#     'description': 'Sezen Aksu Resmi YouTube Kanalına Abone Olun: https://goo.gl/xPnZlA ================================= Resmi Web ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/MsaGFWTQ9ug/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/MsaGFWTQ9ug/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/MsaGFWTQ9ug/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sezen Aksu',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-10-16T15:00:26Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'PbYBW8IFlqmRMjf4Ef21UzGAEKM',
#    'id': {'kind': 'youtube#video', 'videoId': 'XgXtm59kHTY'},
#    'snippet': {'publishedAt': '2023-10-12T21:00:14Z',
#     'channelId': 'UC6OI7Crv96jgra5pwJNDFRQ',
#     'title': 'Sezen Aksu - Rahatı Kaçan Ağaç (Official Music Video)',
#     'description': 'Rahatı Kaçan Ağaç Tanıdığım bir ağaç var Etlik bağlarına yakın Saadetin adını bile duymamış Tanrının işine bakın. Geceyi ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/XgXtm59kHTY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/XgXtm59kHTY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/XgXtm59kHTY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sezen Aksu',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-10-12T21:00:14Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'aYOTxcmZLF7OE-ssD8PEt_WxpDE',
#    'id': {'kind': 'youtube#video', 'videoId': '-f9r6m_iQRo'},
#    'snippet': {'publishedAt': '2023-10-08T10:00:00Z',
#     'channelId': 'UC6OI7Crv96jgra5pwJNDFRQ',
#     'title': 'Sezen Aksu - Ben de Yoluma Giderim #SezenAksu #MinikSerçe #bendeyolumagiderim  #Shorts',
#     'description': 'Sezen Aksu Resmi YouTube Kanalına Abone Olun: https://goo.gl/xPnZlA ================================= Resmi Web ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/-f9r6m_iQRo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/-f9r6m_iQRo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/-f9r6m_iQRo/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sezen Aksu',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-10-08T10:00:00Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'aT9vp-DUsT1rBq_SxflsF2U6o2U',
#    'id': {'kind': 'youtube#video', 'videoId': '6MLwrXvqq4g'},
#    'snippet': {'publishedAt': '2023-10-04T15:00:05Z',
#     'channelId': 'UC6OI7Crv96jgra5pwJNDFRQ',
#     'title': 'Sezen Aksu - Rakkas #SezenAksu #MinikSerçe #Rakkas #Shorts',
#     'description': 'Sezen Aksu Resmi YouTube Kanalına Abone Olun: https://goo.gl/xPnZlA ================================= Resmi Web ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/6MLwrXvqq4g/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/6MLwrXvqq4g/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/6MLwrXvqq4g/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sezen Aksu',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-10-04T15:00:05Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '0pq2X0b1Q_acYLSnT1s6maFAYX4',
#    'id': {'kind': 'youtube#video', 'videoId': 'mFBa6_FZA6Y'},
#    'snippet': {'publishedAt': '2023-10-01T10:00:28Z',
#     'channelId': 'UC6OI7Crv96jgra5pwJNDFRQ',
#     'title': 'Sezen Aksu - Belki De Aşk Lazım Değildir #SezenAksu #MinikSerçe #Throwback #Shorts',
#     'description': 'Sezen Aksu Resmi YouTube Kanalına Abone Olun: https://goo.gl/xPnZlA ================================= Resmi Web ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/mFBa6_FZA6Y/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/mFBa6_FZA6Y/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/mFBa6_FZA6Y/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sezen Aksu',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-10-01T10:00:28Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'LmW7bwgUbMldG8abjyJW_9lraJc',
#    'id': {'kind': 'youtube#video', 'videoId': '2V4s3QujDVM'},
#    'snippet': {'publishedAt': '2023-09-27T15:00:02Z',
#     'channelId': 'UC6OI7Crv96jgra5pwJNDFRQ',
#     'title': 'Sezen Aksu - Biliyorsun #SezenAksu #MinikSerçe #Throwback #Shorts',
#     'description': 'Sezen Aksu Resmi YouTube Kanalına Abone Olun: https://goo.gl/xPnZlA ================================= Resmi Web ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/2V4s3QujDVM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/2V4s3QujDVM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/2V4s3QujDVM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sezen Aksu',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-09-27T15:00:02Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'e2ybG4g7H81VNpqJ71G1Rb77rQA',
#    'id': {'kind': 'youtube#video', 'videoId': 'muOMSxHW6uU'},
#    'snippet': {'publishedAt': '2023-07-20T21:00:35Z',
#     'channelId': 'UC6OI7Crv96jgra5pwJNDFRQ',
#     'title': 'Sezen Aksu - Kıra Döke (Official Music Video)',
#     'description': 'Epeyce bir aradan sonra, baktım yeni albümün ne zaman biteceği belli değil, bir ara sıcak şarkıyla azıcık gülümseyelim istedim.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/muOMSxHW6uU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/muOMSxHW6uU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/muOMSxHW6uU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sezen Aksu',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-07-20T21:00:35Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'P6uHynfClDUcJAVDh3JRos5BrCQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'tA598nLajOc'},
#    'snippet': {'publishedAt': '2023-06-13T09:00:37Z',
#     'channelId': 'UC6OI7Crv96jgra5pwJNDFRQ',
#     'title': 'Sezen Aksu - Firuze (Lyrics | Şarkı Sözleri)',
#     'description': 'Firuze (Firuze, 1982) Söz: Aysel Gürel Beste: Attila Özdemiroğlu Düzenleme: Attila Özdemiroğlu "Firuze" şarkı sözleri: Bir gün ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/tA598nLajOc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/tA598nLajOc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/tA598nLajOc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sezen Aksu',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-06-13T09:00:37Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '3wWBDBKact1G8Z-X5FYMOw2Q1Z4',
#    'id': {'kind': 'youtube#video', 'videoId': 'hC7ye3Iunxs'},
#    'snippet': {'publishedAt': '2022-12-31T10:00:31Z',
#     'channelId': 'UC6OI7Crv96jgra5pwJNDFRQ',
#     'title': 'Sezen Aksu - Şarkı Söylemek Lazım (Yılbaşı Özel Video)',
#     'description': '"2023\'te herkesin biricik ve çok değerli olduğunu fark etmesi, anlaması, hissetmesi; ve bu değere sahip çıkması dileğiyle…',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/hC7ye3Iunxs/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/hC7ye3Iunxs/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/hC7ye3Iunxs/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sezen Aksu',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-12-31T10:00:31Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'f1tsQG4Fj0cTiz7T-LHiXgcXeho',
#    'id': {'kind': 'youtube#video', 'videoId': 'gInR24wjdEQ'},
#    'snippet': {'publishedAt': '2022-12-06T08:29:18Z',
#     'channelId': 'UC6OI7Crv96jgra5pwJNDFRQ',
#     'title': 'Sezen Aksu - Denge (Lyrics | Şarkı Sözleri)',
#     'description': 'Denge (Adı Bende Saklı, 1998) Şiir: Turgut Uyar Müzik: Sezen Aksu, Aykut Gürel Düzenleme: Aykut Gürel "Denge" şarkı sözleri: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/gInR24wjdEQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/gInR24wjdEQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/gInR24wjdEQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sezen Aksu',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-12-06T08:29:18Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '8HEO4od8jAnLy7mOGjnv8qI2LYA',
#    'id': {'kind': 'youtube#video', 'videoId': 'ZaYxJY4BThE'},
#    'snippet': {'publishedAt': '2022-11-22T12:23:07Z',
#     'channelId': 'UC6OI7Crv96jgra5pwJNDFRQ',
#     'title': 'Sezen Aksu - Şinanay #SezenAksu #MinikSerçe #Throwback #Shorts',
#     'description': 'Sezen Aksu Resmi YouTube Kanalına Abone Olun: https://goo.gl/xPnZlA ================================= Resmi Web ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ZaYxJY4BThE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ZaYxJY4BThE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ZaYxJY4BThE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sezen Aksu',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-11-22T12:23:07Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '3hcrOROvv8QuHB3vc1CusDiAAxY',
#    'id': {'kind': 'youtube#video', 'videoId': 'gwhyktn99uo'},
#    'snippet': {'publishedAt': '2022-10-25T08:00:23Z',
#     'channelId': 'UC6OI7Crv96jgra5pwJNDFRQ',
#     'title': 'Sezen Aksu - Şimal Yıldızı (Lyrics | Şarkı Sözleri)',
#     'description': 'Şimal Yıldızı (Adı Bende Saklı, 1998) Söz: Sezen Aksu, Meral Okay Müzik: Sezen Aksu Düzenleme: Aşkın Arsunan "Şimal Yıldızı" ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/gwhyktn99uo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/gwhyktn99uo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/gwhyktn99uo/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sezen Aksu',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-10-25T08:00:23Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'hjWfsDp9ikF8JItRVQpQAeTsepo',
#    'id': {'kind': 'youtube#video', 'videoId': 'vSmxJS0vyS8'},
#    'snippet': {'publishedAt': '2022-09-13T08:00:30Z',
#     'channelId': 'UC6OI7Crv96jgra5pwJNDFRQ',
#     'title': 'Sezen Aksu - İnce Mevzu (Lyrics | Şarkı Sözleri)',
#     'description': 'İnce Mevzu (Adı Bende Saklı, 1998) Söz: Sezen Aksu, Mustafa Sandal Müzik: Mustafa Sandal Düzenleme: Mustafa Sandal "İnce ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/vSmxJS0vyS8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/vSmxJS0vyS8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/vSmxJS0vyS8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sezen Aksu',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-09-13T08:00:30Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'xwR9sEE_D6Y2xNS621poYFt_Hj8',
#    'id': {'kind': 'youtube#video', 'videoId': 'xVaKYpxjfs0'},
#    'snippet': {'publishedAt': '2022-07-28T21:00:35Z',
#     'channelId': 'UC6OI7Crv96jgra5pwJNDFRQ',
#     'title': 'Sezen Aksu - Rütbe (Lyrics | Şarkı Sözleri)',
#     'description': 'Şarkı Sözleri: Basıp gitmek istiyorum buralardan Kendimi doldurup trenlere Bir daha hiç basmadan frenlere Gördüğüm bütün ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/xVaKYpxjfs0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/xVaKYpxjfs0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/xVaKYpxjfs0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sezen Aksu',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-07-28T21:00:35Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '5AuYpKaHnq7SXvWCZXtnZK__RI4',
#    'id': {'kind': 'youtube#video', 'videoId': 'R7epdPOyuRE'},
#    'snippet': {'publishedAt': '2022-04-28T21:00:16Z',
#     'channelId': 'UC6OI7Crv96jgra5pwJNDFRQ',
#     'title': 'Sezen Aksu - Her Şeye Rağmen (Official Video)',
#     'description': 'Şarkı Sözleri: Kan, keder, gözyaşı ve ümit her şeye rağmen Yaşamak inadına, vazgeçmiyor sızım sızım sızlarken Kaç bin yıllık bir ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/R7epdPOyuRE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/R7epdPOyuRE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/R7epdPOyuRE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sezen Aksu',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-04-28T21:00:16Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'r_WUsXRn_ewse-fRe2GLJeEabLQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'TwKKGO4bnPI'},
#    'snippet': {'publishedAt': '2022-04-18T08:00:07Z',
#     'channelId': 'UC6OI7Crv96jgra5pwJNDFRQ',
#     'title': 'Sezen Aksu - Erkekler (1997) #SezenAksu #MinikSerçe #Throwback #Shorts',
#     'description': "Klibin tamamını izlemek için: https://youtu.be/EX_hCGodzlM Sezen Aksu - Erkekler ('Düğün ve Cenaze' - 1997) Söz: Sezen Aksu ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/TwKKGO4bnPI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/TwKKGO4bnPI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/TwKKGO4bnPI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sezen Aksu',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-04-18T08:00:07Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'WiCAoSvQqE17X-03DR1ZqkdV4Hw',
#    'id': {'kind': 'youtube#video', 'videoId': 'yjvYFVBSE6I'},
#    'snippet': {'publishedAt': '2022-04-15T08:00:33Z',
#     'channelId': 'UC6OI7Crv96jgra5pwJNDFRQ',
#     'title': 'Sezen Aksu - Güllerim Soldu (1991) #SezenAksu #MinikSerçe #Throwback #Shorts',
#     'description': "Klibin tamamını izlemek için: https://youtu.be/a6yhhVnLalg Sezen Aksu - Güllerim Soldu ('Gülümse' - 1991) Söz: Sezen Aksu ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/yjvYFVBSE6I/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/yjvYFVBSE6I/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/yjvYFVBSE6I/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sezen Aksu',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-04-15T08:00:33Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Hm-nzRK9fecrRr46BAbh-C3EjSs',
#    'id': {'kind': 'youtube#video', 'videoId': 'hppUAi6s-lI'},
#    'snippet': {'publishedAt': '2022-04-13T08:00:26Z',
#     'channelId': 'UC6OI7Crv96jgra5pwJNDFRQ',
#     'title': 'Sezen Aksu - İhanetten Geri Kalan (2017) #SezenAksu #MinikSerçe #Throwback #Shorts',
#     'description': "Klibin tamamını izlemek için: https://youtu.be/o5Gcgmarvvc Sezen Aksu - İhanetten Geri Kalan ('Biraz Pop Biraz Sezen' - 2017) ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/hppUAi6s-lI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/hppUAi6s-lI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/hppUAi6s-lI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sezen Aksu',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-04-13T08:00:26Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Ros486fjCtvmmWaGURlQR9nHg5Y',
#    'id': {'kind': 'youtube#video', 'videoId': 'PrreJ_HEy6w'},
#    'snippet': {'publishedAt': '2022-04-11T08:00:13Z',
#     'channelId': 'UC6OI7Crv96jgra5pwJNDFRQ',
#     'title': 'Sezen Aksu - Masum Değiliz (1993) #SezenAksu #MinikSerçe #Throwback #Shorts',
#     'description': "Klibin tamamını izlemek için: https://youtu.be/Lc8Nuk2VN-I Sezen Aksu - Masum Değiliz ('Deli Kızın Türküsü' - 1993) Söz: Sezen ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/PrreJ_HEy6w/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/PrreJ_HEy6w/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/PrreJ_HEy6w/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sezen Aksu',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-04-11T08:00:13Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'xXUn586Ts2Qmdswey8gOGwiFsX8',
#    'id': {'kind': 'youtube#video', 'videoId': 'uu8SkX60p6M'},
#    'snippet': {'publishedAt': '2022-04-08T08:00:15Z',
#     'channelId': 'UC6OI7Crv96jgra5pwJNDFRQ',
#     'title': 'Sezen Aksu - Her Şeyi Yak (1991) #SezenAksu #MinikSerçe #Throwback #Shorts',
#     'description': "Klibin tamamını izlemek için: https://youtu.be/u5OVXkyxn1Q Sezen Aksu - Her Şeyi Yak ('Gülümse' - 1991) Söz: Sezen Aksu ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/uu8SkX60p6M/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/uu8SkX60p6M/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/uu8SkX60p6M/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sezen Aksu',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-04-08T08:00:15Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Ajilydg1Q-CxX9IP6KNCnsFZ-w4',
#    'id': {'kind': 'youtube#video', 'videoId': '5pXs6FjoOFE'},
#    'snippet': {'publishedAt': '2022-04-06T08:00:04Z',
#     'channelId': 'UC6OI7Crv96jgra5pwJNDFRQ',
#     'title': 'Sezen Aksu - Beşik (2008) #SezenAksu #MinikSerçe #Throwback #Shorts',
#     'description': "Klibin tamamını izlemek için: https://youtu.be/mN2w81pri5c Sezen Aksu - Beşik ('Deniz Yıldızı' - 2008) Söz: Sezen Aksu Beste: ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/5pXs6FjoOFE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/5pXs6FjoOFE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/5pXs6FjoOFE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sezen Aksu',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-04-06T08:00:04Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'lItGGaaKaku8GHcxv1Rz-ar4kcU',
#    'id': {'kind': 'youtube#video', 'videoId': 'ix1TPNvlS3c'},
#    'snippet': {'publishedAt': '2022-04-01T11:00:25Z',
#     'channelId': 'UC6OI7Crv96jgra5pwJNDFRQ',
#     'title': 'Sezen Aksu - Ana Dilim Aşk (Lyrics | Şarkı Sözleri)',
#     'description': "Ana Dilim Aşk (Yürüyorum Düş Bahçeleri'nde..., 2009) Söz: Sezen Aksu Müzik: Sezen Aksu Düzenleme: Kıvanç Osman Kutlumuş ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ix1TPNvlS3c/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ix1TPNvlS3c/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ix1TPNvlS3c/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sezen Aksu',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-04-01T11:00:25Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Z6fc86oRkaxEfeSH1pNSbeTq0tg',
#    'id': {'kind': 'youtube#video', 'videoId': 'x3Ly2HSnE6A'},
#    'snippet': {'publishedAt': '2022-03-28T08:00:20Z',
#     'channelId': 'UC6OI7Crv96jgra5pwJNDFRQ',
#     'title': 'Sezen Aksu - Değer mi? (1986) #SezenAksu #Throwback #Shorts',
#     'description': "Klibin tamamını izlemek için: https://youtu.be/Gi-K-ER823c Sezen Aksu - Değer mi? ('Git' - 1986) Söz: Aysel Gürel Beste: Onno ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/x3Ly2HSnE6A/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/x3Ly2HSnE6A/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/x3Ly2HSnE6A/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sezen Aksu',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-03-28T08:00:20Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '6rrj9mIY54ftT5SZB94fswvAUZg',
#    'id': {'kind': 'youtube#video', 'videoId': 'RsfaBzA4bQw'},
#    'snippet': {'publishedAt': '2022-03-25T08:00:09Z',
#     'channelId': 'UC6OI7Crv96jgra5pwJNDFRQ',
#     'title': 'Sezen Aksu - Farkındayım (2003) #SezenAksu #Throwback #Shorts',
#     'description': "Klibin tamamını izlemek için: https://youtu.be/uTSYnM-UxD0 Sezen Aksu - Farkındayım ('Yaz Bitmeden' - 2003) Söz: Sezen Aksu ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/RsfaBzA4bQw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/RsfaBzA4bQw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/RsfaBzA4bQw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sezen Aksu',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-03-25T08:00:09Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'uPy9DH3nHMsVpq6Fz2sLPE9Br1c',
#    'id': {'kind': 'youtube#video', 'videoId': 'UVADZfalgQk'},
#    'snippet': {'publishedAt': '2022-03-23T08:00:16Z',
#     'channelId': 'UC6OI7Crv96jgra5pwJNDFRQ',
#     'title': 'Sezen Aksu - Seni Yerler (1996) #SezenAksu #Throwback #Shorts',
#     'description': "Klibin tamamını izlemek için: https://youtu.be/IVE00F-2ZCw Sezen Aksu - Seni Yerler ('Düş Bahçeleri' - 1996) Söz & Beste: Sezen ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/UVADZfalgQk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/UVADZfalgQk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/UVADZfalgQk/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sezen Aksu',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-03-23T08:00:16Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'jB0L3EnuT-rNMarHpAztCjTNn5A',
#    'id': {'kind': 'youtube#video', 'videoId': 'zCPZjf_MVUk'},
#    'snippet': {'publishedAt': '2022-03-21T08:00:12Z',
#     'channelId': 'UC6OI7Crv96jgra5pwJNDFRQ',
#     'title': 'Sezen Aksu - Sarı Odalar (2000) #SezenAksu #Throwback #Shorts',
#     'description': "Klibin tamamını izlemek için: https://youtu.be/vjU-RcwSwO4 Sezen Aksu - Sarı Odalar ('Deliveren' - 2000) Söz & Beste: Sezen ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/zCPZjf_MVUk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/zCPZjf_MVUk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/zCPZjf_MVUk/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sezen Aksu',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-03-21T08:00:12Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '8fH9E_J-AeP5npvIRMvURYMlN_0',
#    'id': {'kind': 'youtube#video', 'videoId': 'do-enXeqzRg'},
#    'snippet': {'publishedAt': '2022-03-18T08:00:10Z',
#     'channelId': 'UC6OI7Crv96jgra5pwJNDFRQ',
#     'title': 'Sezen Aksu - Onu Alma Beni Al (1995) #SezenAksu #Throwback #Shorts',
#     'description': "Klibin tamamını izlemek için: https://youtu.be/XTNWD9FeZ20 Sezen Aksu - Onu Alma Beni Al ('Işık Doğudan Yükselir' - 1995) Söz: ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/do-enXeqzRg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/do-enXeqzRg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/do-enXeqzRg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sezen Aksu',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-03-18T08:00:10Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'rJ8P3j0VvCVgt2sSwVUxLxIxlAo',
#    'id': {'kind': 'youtube#video', 'videoId': '83RFuNDB-zA'},
#    'snippet': {'publishedAt': '2022-03-16T08:00:05Z',
#     'channelId': 'UC6OI7Crv96jgra5pwJNDFRQ',
#     'title': 'Sezen Aksu - Kaç Yıl Geçti Aradan (1978) #SezenAksu #Throwback #Shorts',
#     'description': "Klibin tamamını izlemek için: https://youtu.be/vpc7KnLcgxY Sezen Aksu - Kaç Yıl Geçti Aradan ('Serçe' - 1978) Söz & Beste: ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/83RFuNDB-zA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/83RFuNDB-zA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/83RFuNDB-zA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sezen Aksu',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-03-16T08:00:05Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'kXb6NaF2SbUlsu2WBdrWx2IdYwk',
#    'id': {'kind': 'youtube#video', 'videoId': 'Pjgk_5Mlb0k'},
#    'snippet': {'publishedAt': '2022-03-14T08:00:06Z',
#     'channelId': 'UC6OI7Crv96jgra5pwJNDFRQ',
#     'title': 'Sezen Aksu - Git (1986) #SezenAksu #Throwback #Shorts',
#     'description': "Klibin tamamını izlemek için: https://youtu.be/VCXJmVoDuuo Sezen Aksu - Git ('Git' - 1986) Söz: Sezen Aksu Beste: Onno Tunç.",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Pjgk_5Mlb0k/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Pjgk_5Mlb0k/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Pjgk_5Mlb0k/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sezen Aksu',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-03-14T08:00:06Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'okkA5OLAV6ciuSK-I8pztvt03XA',
#    'id': {'kind': 'youtube#video', 'videoId': 'txet741U_bw'},
#    'snippet': {'publishedAt': '2022-03-11T08:00:18Z',
#     'channelId': 'UC6OI7Crv96jgra5pwJNDFRQ',
#     'title': 'Sezen Aksu - Geri Dön (1984) #SezenAksu #Throwback #Shorts',
#     'description': "Klibin tamamını izlemek için: https://youtu.be/3_961n_y4TA Sezen Aksu - Geri Dön ('Sen Ağlama' - 1984) Söz: Sezen Aksu Beste: ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/txet741U_bw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/txet741U_bw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/txet741U_bw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sezen Aksu',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-03-11T08:00:18Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '4iCtDDu6zGbTChcHPzDcZKTBWtY',
#    'id': {'kind': 'youtube#video', 'videoId': 'Tnf6saLmGy8'},
#    'snippet': {'publishedAt': '2022-03-09T08:00:12Z',
#     'channelId': 'UC6OI7Crv96jgra5pwJNDFRQ',
#     'title': 'Sezen Aksu - Unuttun Mu Beni (2011) #SezenAksu #Throwback #Shorts',
#     'description': "Klibin tamamını izlemek için: https://youtu.be/5k5P_Eqy4xo Sezen Aksu - Unuttun Mu Beni ('Öptüm' - 2011) Söz & Beste: Sezen ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Tnf6saLmGy8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Tnf6saLmGy8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Tnf6saLmGy8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sezen Aksu',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-03-09T08:00:12Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'tdyoU8OImBFhZopHWSYHeev362M',
#    'id': {'kind': 'youtube#video', 'videoId': 'NWbb7TR92Tc'},
#    'snippet': {'publishedAt': '2022-03-07T08:00:16Z',
#     'channelId': 'UC6OI7Crv96jgra5pwJNDFRQ',
#     'title': 'Sezen Aksu - Tutuklu (1998) #SezenAksu #Throwback #Shorts',
#     'description': "Klibin tamamını izlemek için: https://youtu.be/fEdZGZpAZZk Sezen Aksu - Tutuklu ('Adı Bende Saklı' - 1998) Söz & Beste: Sezen ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/NWbb7TR92Tc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/NWbb7TR92Tc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/NWbb7TR92Tc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sezen Aksu',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-03-07T08:00:16Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '8aif04AWhzxycWsP_AUw88-Rpb8',
#    'id': {'kind': 'youtube#video', 'videoId': 'TbBYUO8zvoM'},
#    'snippet': {'publishedAt': '2021-12-30T10:00:12Z',
#     'channelId': 'UC6OI7Crv96jgra5pwJNDFRQ',
#     'title': 'Sezen Aksu - Şahane Bir Şey Yaşamak (Lyrics | Şarkı Sözleri)',
#     'description': 'Yıl 2022 arkadaşlar… Size güzel bir yeni yıl dilemek için bir sürü cümle geçti aklımdan, hiçbiri içime sinmedi. O nedenle ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/TbBYUO8zvoM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/TbBYUO8zvoM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/TbBYUO8zvoM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sezen Aksu',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-12-30T10:00:12Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'aCDWWEb7CztT2KmBIdPSiODmC04',
#    'id': {'kind': 'youtube#video', 'videoId': 'fjjM9DRwfN8'},
#    'snippet': {'publishedAt': '2021-11-25T21:00:13Z',
#     'channelId': 'UC6OI7Crv96jgra5pwJNDFRQ',
#     'title': 'Sezen Aksu - Belki De Aşk Lazım Değildir  (Official Video)',
#     'description': 'Şarkı Sözleri: Öpeyim de geçsin mi? Acıyor mu çok kesilen yer? Bilirim ah, ne hüzündür Terim tuzundur, bir izin ver Tanıdım ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/fjjM9DRwfN8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/fjjM9DRwfN8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/fjjM9DRwfN8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sezen Aksu',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-11-25T21:00:13Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'sjpTLR-6jkoaAASVTCT3SWQzmEc',
#    'id': {'kind': 'youtube#video', 'videoId': 'bqC65QXi_JE'},
#    'snippet': {'publishedAt': '2021-09-16T21:00:11Z',
#     'channelId': 'UC6OI7Crv96jgra5pwJNDFRQ',
#     'title': 'Sezen Aksu - Yandı İçim (Official Video)',
#     'description': 'Şarkı Sözleri: E pek kolay geçmedi günler Gelenler, gidenler, neler neler... Delirdim, delirdim, delirdim Çok öldüresim vardı, çok ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/bqC65QXi_JE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/bqC65QXi_JE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/bqC65QXi_JE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sezen Aksu',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-09-16T21:00:11Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'k2TFz8eN72gFggwo_RsAoe8WMu4',
#    'id': {'kind': 'youtube#video', 'videoId': 'Wc3xHIJoxF4'},
#    'snippet': {'publishedAt': '2021-07-15T21:00:10Z',
#     'channelId': 'UC6OI7Crv96jgra5pwJNDFRQ',
#     'title': 'Sezen Aksu - Onursuz Olabilir Aşk  (Official Video)',
#     'description': "Bu dinlediğiniz demo şarkı Okay Barış tarafından 2017'de “Artık Sevilmiyor Böyle” albümünde seslendirilmiştir. O yorumu ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Wc3xHIJoxF4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Wc3xHIJoxF4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Wc3xHIJoxF4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sezen Aksu',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-07-15T21:00:10Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'uDl3mU54eAE1wc8sSJtH1F0bLNo',
#    'id': {'kind': 'youtube#video', 'videoId': 'LXWPeim0CU4'},
#    'snippet': {'publishedAt': '2021-06-24T08:00:07Z',
#     'channelId': 'UC6OI7Crv96jgra5pwJNDFRQ',
#     'title': 'Sezen Aksu - Ruhuma Asla (Kivanch K. Remix) (Lyrics | Şarkı Sözleri)',
#     'description': 'Ruhuma Asla (Adı Bende Saklı, 1998) Söz: Sezen Aksu Müzik: Sezen Aksu Düzenleme: Kıvanç Osman Kutlumuş "Ruhuma Asla" ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/LXWPeim0CU4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/LXWPeim0CU4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/LXWPeim0CU4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sezen Aksu',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-06-24T08:00:07Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '7XzHIEqfhkYnBs0t-fGBdf4S65Y',
#    'id': {'kind': 'youtube#video', 'videoId': 'DWKapv81V4c'},
#    'snippet': {'publishedAt': '2021-06-10T21:00:05Z',
#     'channelId': 'UC6OI7Crv96jgra5pwJNDFRQ',
#     'title': 'Sezen Aksu - Deli Divane  (Official Video)',
#     'description': 'Ne olur korksam, ne olur korkmasam? Duruyor mu damarda akacak kan? Ne göreyim, fırlamış yerinden Yetişemedim yüreğimin ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/DWKapv81V4c/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/DWKapv81V4c/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/DWKapv81V4c/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sezen Aksu',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-06-10T21:00:05Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'fJwkjsWjtCCaeDI2liDI9jCmMPo',
#    'id': {'kind': 'youtube#video', 'videoId': 'N8m-KiJxJoo'},
#    'snippet': {'publishedAt': '2021-05-25T12:00:07Z',
#     'channelId': 'UC6OI7Crv96jgra5pwJNDFRQ',
#     'title': 'Sezen Aksu - Adı Menekşe (Lyrics | Şarkı Sözleri)',
#     'description': 'Adı Menekşe (Adı Bende Saklı, 1998) Söz: Sezen Aksu, Meral Okay Müzik: Sezen Aksu, Aşkın Arsunan Düzenleme: Kıvanç ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/N8m-KiJxJoo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/N8m-KiJxJoo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/N8m-KiJxJoo/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sezen Aksu',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-05-25T12:00:07Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '2EWlvAlP-i6C7lJqwboa5OhZz7c',
#    'id': {'kind': 'youtube#video', 'videoId': 'PrJULYp6XJc'},
#    'snippet': {'publishedAt': '2021-05-13T19:00:07Z',
#     'channelId': 'UC6OI7Crv96jgra5pwJNDFRQ',
#     'title': 'Sezen Aksu - Erkek Güzeli (Lyrics | Şarkı Sözleri)',
#     'description': "Erkek Güzeli (Adı Bende Saklı, 1998) Söz: Sezen Aksu Müzik: Sezen Aksu Düzenleme: Murat Yeter ''Erkek Güzeli'' şarkı sözleri: ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/PrJULYp6XJc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/PrJULYp6XJc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/PrJULYp6XJc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sezen Aksu',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-05-13T19:00:07Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'VCTRYEEI9CsQidSVNFF___jQ8BI',
#    'id': {'kind': 'youtube#video', 'videoId': 'gi4koQNYrGw'},
#    'snippet': {'publishedAt': '2021-05-04T11:34:35Z',
#     'channelId': 'UC6OI7Crv96jgra5pwJNDFRQ',
#     'title': 'Sezen Aksu - Kaderim (Lyrics | Şarkı Sözleri)',
#     'description': 'Kaderim (Adı Bende Saklı, 1998) Söz: Sezen Aksu Müzik: Sezen Aksu Düzenleme: Kıvanç Osman Kutlumuş Şarkı Sözleri Az ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/gi4koQNYrGw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/gi4koQNYrGw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/gi4koQNYrGw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sezen Aksu',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-05-04T11:34:35Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'TvovpM2lYcFmtotJ3qJEVphUVo0',
#    'id': {'kind': 'youtube#video', 'videoId': 'IqkKxPeWBPQ'},
#    'snippet': {'publishedAt': '2021-04-01T21:00:19Z',
#     'channelId': 'UC6OI7Crv96jgra5pwJNDFRQ',
#     'title': 'Sezen Aksu, Kardeş Türküler &amp; Ara Dinkjian - Hakim Bey (Official Video)',
#     'description': '"Hakim Bey, ilk olarak 1996 da sevgili dostum Zülfü Livaneli tarafından seslendirilmişti. Daha sonra 1998\'de Levent Yüksel ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/IqkKxPeWBPQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/IqkKxPeWBPQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/IqkKxPeWBPQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sezen Aksu',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-04-01T21:00:19Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '6ZU-6YdAnWoYvph-Riw-M_IuR10',
#    'id': {'kind': 'youtube#video', 'videoId': 'KzzIZNQ2bmY'},
#    'snippet': {'publishedAt': '2021-03-11T08:00:09Z',
#     'channelId': 'UC6OI7Crv96jgra5pwJNDFRQ',
#     'title': 'Sezen Aksu - Tutuklu (Lyrics | Şarkı Sözleri)',
#     'description': 'Tutuklu (Adı Bende Saklı, 1998) Söz: Sezen Aksu Müzik: Sezen Aksu Düzenleme: Kıvanç Osman Kutlumuş Ne senden öncesi Ne ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/KzzIZNQ2bmY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/KzzIZNQ2bmY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/KzzIZNQ2bmY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sezen Aksu',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-03-11T08:00:09Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Hlht_mwFUqFnKZPgOSyB_qDhWrI',
#    'id': {'kind': 'youtube#video', 'videoId': 'eMlIhNIZHio'},
#    'snippet': {'publishedAt': '2021-02-02T19:00:19Z',
#     'channelId': 'UC6OI7Crv96jgra5pwJNDFRQ',
#     'title': 'Sezen Aksu - Affet (Official Video)',
#     'description': 'Senden daha öncesi yok ki Çoktan kaldırdım çatıya Böyle bir saflık yok ki Bakakaldım Kimlerdensin nerelerdensin Değmedi mi kir ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/eMlIhNIZHio/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/eMlIhNIZHio/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/eMlIhNIZHio/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Sezen Aksu',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-02-02T19:00:19Z'}}]}

# %%
response["items"][0]
# Out:
# {'kind': 'youtube#searchResult',
#  'etag': 'QsGPahY_L8jBpYCSPevqWvwE84E',
#  'id': {'kind': 'youtube#video', 'videoId': 'SwFG0k9ezHg'},
#  'snippet': {'publishedAt': '2023-12-03T17:00:17Z',
#   'channelId': 'UC6OI7Crv96jgra5pwJNDFRQ',
#   'title': 'Sezen Aksu - Gidiyorum #SezenAksu #MinikSerçe #gidiyorum #Shorts',
#   'description': 'Sezen Aksu Resmi YouTube Kanalına Abone Olun: https://goo.gl/xPnZlA ================================= Resmi Web ...',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/SwFG0k9ezHg/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/SwFG0k9ezHg/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/SwFG0k9ezHg/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'Sezen Aksu',
#   'liveBroadcastContent': 'none',
#   'publishTime': '2023-12-03T17:00:17Z'}}

# %%
response["items"][0]['id']['videoId']
# Out:
# 'SwFG0k9ezHg'

# %%
response["items"][0]['snippet']['title']
# Out:
# 'Sezen Aksu - Gidiyorum #SezenAksu #MinikSerçe #gidiyorum #Shorts'

# %%
response["items"][0]['snippet']['publishedAt']
# Out:
# '2023-12-03T17:00:17Z'

# %%
video_title = response["items"][0]['snippet']['title']
video_id = response["items"][0]['id']['videoId']
upload_time = response["items"][0]['snippet']['publishedAt']
upload_time = str(upload_time).split("T")[0]
print(video_title)
print(video_id)
print(upload_time)
# Out:
# Sezen Aksu - Gidiyorum #SezenAksu #MinikSerçe #gidiyorum #Shorts
# SwFG0k9ezHg
# 2023-12-03

# %%
# for loop in response 
for video in response["items"]:
    if video['id']['kind'] == 'youtube#video':
        video_title = video['snippet']['title']
        video_id = video['id']['videoId']
        upload_date = video['snippet']['publishedAt']
        upload_date = str(upload_time).split("T")[0]

        video_stats_url = "https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+YOUTUBE_API_KEY
        video_stats_response = requests.get(video_stats_url).json()
        view_count = video_stats_response['items'][0]["statistics"]["viewCount"]
        like_count = video_stats_response['items'][0]["statistics"]["likeCount"]

        print(video_title)
        print(video_id)
        print(upload_date)
        print(view_count)
        print(like_count)
        print("\n")
# Out:
# Sezen Aksu - Gidiyorum #SezenAksu #MinikSerçe #gidiyorum #Shorts
# SwFG0k9ezHg
# 2023-12-03
# 19327
# 1226
#
#
# Sezen Aksu - Keskin Bıçak #SezenAksu #MinikSerçe #keskinbıçak #Shorts
# EF9NO-fvs3c
# 2023-12-03
# 16173
# 913
#
#
# Sezen Aksu - Erkek Güzeli #SezenAksu #MinikSerçe #erkekgüzeli  #Shorts
# _y08PXbalHg
# 2023-12-03
# 25480
# 1408
#
#
# Sezen Aksu - Yanıyom Ölüyom (Canlı Performans)
# 7HNOJisHhbg
# 2023-12-03
# 371917
# 5425
#
#
# Sezen Aksu - Değer mi? #SezenAksu #MinikSerçe #değermi  #Shorts
# EOADibxhQms
# 2023-12-03
# 8879
# 594
#
#
# Sezen Aksu - Yanmışım Sönmüşüm Ben #SezenAksu #MinikSerçe #yanmışımsönmüşümben #Shorts
# nYUb6k9VB_o
# 2023-12-03
# 43092
# 1934
#
#
# Sezen Aksu - Rahatı Kaçan Ağaç #SezenAksu #MinikSerçe #rahatıkaçanağaç #Shorts
# MsaGFWTQ9ug
# 2023-12-03
# 18504
# 743
#
#
# Sezen Aksu - Rahatı Kaçan Ağaç (Official Music Video)
# XgXtm59kHTY
# 2023-12-03
# 411716
# 7912
#
#
# Sezen Aksu - Ben de Yoluma Giderim #SezenAksu #MinikSerçe #bendeyolumagiderim  #Shorts
# -f9r6m_iQRo
# 2023-12-03
# 72177
# 4615
#
#
# Sezen Aksu - Rakkas #SezenAksu #MinikSerçe #Rakkas #Shorts
# 6MLwrXvqq4g
# 2023-12-03
# 19634
# 891
#
#
# Sezen Aksu - Belki De Aşk Lazım Değildir #SezenAksu #MinikSerçe #Throwback #Shorts
# mFBa6_FZA6Y
# 2023-12-03
# 35676
# 1826
#
#
# Sezen Aksu - Biliyorsun #SezenAksu #MinikSerçe #Throwback #Shorts
# 2V4s3QujDVM
# 2023-12-03
# 150095
# 9229
#
#
# Sezen Aksu - Kıra Döke (Official Music Video)
# muOMSxHW6uU
# 2023-12-03
# 2169733
# 20754
#
#
# Sezen Aksu - Firuze (Lyrics | Şarkı Sözleri)
# tA598nLajOc
# 2023-12-03
# 9468982
# 37974
#
#
# Sezen Aksu - Şarkı Söylemek Lazım (Yılbaşı Özel Video)
# hC7ye3Iunxs
# 2023-12-03
# 325883
# 3769
#
#
# Sezen Aksu - Denge (Lyrics | Şarkı Sözleri)
# gInR24wjdEQ
# 2023-12-03
# 692367
# 7028
#
#
# Sezen Aksu - Şinanay #SezenAksu #MinikSerçe #Throwback #Shorts
# ZaYxJY4BThE
# 2023-12-03
# 98136
# 2342
#
#
# Sezen Aksu - Şimal Yıldızı (Lyrics | Şarkı Sözleri)
# gwhyktn99uo
# 2023-12-03
# 238039
# 4489
#
#
# Sezen Aksu - İnce Mevzu (Lyrics | Şarkı Sözleri)
# vSmxJS0vyS8
# 2023-12-03
# 290398
# 4590
#
#
# Sezen Aksu - Rütbe (Lyrics | Şarkı Sözleri)
# xVaKYpxjfs0
# 2023-12-03
# 448158
# 10897
#
#
# Sezen Aksu - Her Şeye Rağmen (Official Video)
# R7epdPOyuRE
# 2023-12-03
# 1353603
# 25110
#
#
# Sezen Aksu - Erkekler (1997) #SezenAksu #MinikSerçe #Throwback #Shorts
# TwKKGO4bnPI
# 2023-12-03
# 85271
# 1823
#
#
# Sezen Aksu - Güllerim Soldu (1991) #SezenAksu #MinikSerçe #Throwback #Shorts
# yjvYFVBSE6I
# 2023-12-03
# 578203
# 16598
#
#
# Sezen Aksu - İhanetten Geri Kalan (2017) #SezenAksu #MinikSerçe #Throwback #Shorts
# hppUAi6s-lI
# 2023-12-03
# 171481
# 6629
#
#
# Sezen Aksu - Masum Değiliz (1993) #SezenAksu #MinikSerçe #Throwback #Shorts
# PrreJ_HEy6w
# 2023-12-03
# 113034
# 4253
#
#
# Sezen Aksu - Her Şeyi Yak (1991) #SezenAksu #MinikSerçe #Throwback #Shorts
# uu8SkX60p6M
# 2023-12-03
# 98960
# 4026
#
#
# Sezen Aksu - Beşik (2008) #SezenAksu #MinikSerçe #Throwback #Shorts
# 5pXs6FjoOFE
# 2023-12-03
# 49436
# 1453
#
#
# Sezen Aksu - Ana Dilim Aşk (Lyrics | Şarkı Sözleri)
# ix1TPNvlS3c
# 2023-12-03
# 133294
# 3176
#
#
# Sezen Aksu - Değer mi? (1986) #SezenAksu #Throwback #Shorts
# x3Ly2HSnE6A
# 2023-12-03
# 38506
# 1775
#
#
# Sezen Aksu - Farkındayım (2003) #SezenAksu #Throwback #Shorts
# RsfaBzA4bQw
# 2023-12-03
# 36118
# 1532
#
#
# Sezen Aksu - Seni Yerler (1996) #SezenAksu #Throwback #Shorts
# UVADZfalgQk
# 2023-12-03
# 40032
# 1372
#
#
# Sezen Aksu - Sarı Odalar (2000) #SezenAksu #Throwback #Shorts
# zCPZjf_MVUk
# 2023-12-03
# 29653
# 1324
#
#
# Sezen Aksu - Onu Alma Beni Al (1995) #SezenAksu #Throwback #Shorts
# do-enXeqzRg
# 2023-12-03
# 42507
# 1251
#
#
# Sezen Aksu - Kaç Yıl Geçti Aradan (1978) #SezenAksu #Throwback #Shorts
# 83RFuNDB-zA
# 2023-12-03
# 38860
# 1834
#
#
# Sezen Aksu - Git (1986) #SezenAksu #Throwback #Shorts
# Pjgk_5Mlb0k
# 2023-12-03
# 66873
# 3380
#
#
# Sezen Aksu - Geri Dön (1984) #SezenAksu #Throwback #Shorts
# txet741U_bw
# 2023-12-03
# 80867
# 4838
#
#
# Sezen Aksu - Unuttun Mu Beni (2011) #SezenAksu #Throwback #Shorts
# Tnf6saLmGy8
# 2023-12-03
# 191418
# 6819
#
#
# Sezen Aksu - Tutuklu (1998) #SezenAksu #Throwback #Shorts
# NWbb7TR92Tc
# 2023-12-03
# 92860
# 4495
#
#
# Sezen Aksu - Şahane Bir Şey Yaşamak (Lyrics | Şarkı Sözleri)
# TbBYUO8zvoM
# 2023-12-03
# 7386765
# 67550
#
#
# Sezen Aksu - Belki De Aşk Lazım Değildir  (Official Video)
# fjjM9DRwfN8
# 2023-12-03
# 3734346
# 53556
#
#
# Sezen Aksu - Yandı İçim (Official Video)
# bqC65QXi_JE
# 2023-12-03
# 4258798
# 40012
#
#
# Sezen Aksu - Onursuz Olabilir Aşk  (Official Video)
# Wc3xHIJoxF4
# 2023-12-03
# 8768723
# 95646
#
#
# Sezen Aksu - Ruhuma Asla (Kivanch K. Remix) (Lyrics | Şarkı Sözleri)
# LXWPeim0CU4
# 2023-12-03
# 813035
# 10072
#
#
# Sezen Aksu - Deli Divane  (Official Video)
# DWKapv81V4c
# 2023-12-03
# 7136853
# 66206
#
#
# Sezen Aksu - Adı Menekşe (Lyrics | Şarkı Sözleri)
# N8m-KiJxJoo
# 2023-12-03
# 707690
# 14769
#
#
# Sezen Aksu - Erkek Güzeli (Lyrics | Şarkı Sözleri)
# PrJULYp6XJc
# 2023-12-03
# 5854593
# 28573
#
#
# Sezen Aksu - Kaderim (Lyrics | Şarkı Sözleri)
# gi4koQNYrGw
# 2023-12-03
# 539457
# 11447
#
#
# Sezen Aksu, Kardeş Türküler &amp; Ara Dinkjian - Hakim Bey (Official Video)
# IqkKxPeWBPQ
# 2023-12-03
# 345399
# 6935
#
#
# Sezen Aksu - Tutuklu (Lyrics | Şarkı Sözleri)
# KzzIZNQ2bmY
# 2023-12-03
# 1001484
# 12579
#
#
# Sezen Aksu - Affet (Official Video)
# eMlIhNIZHio
# 2023-12-03
# 18235017
# 167894

# %%
df = pd.DataFrame(columns=["video_id","video_title","upload_date","view_count","like_count"]) 

for video in response['items']:
    if video['id']['kind'] == 'youtube#video':
        video_title = video['snippet']['title']
        video_id = video['id']['videoId']
        upload_date = video['snippet']['publishedAt']
        upload_date= str(upload_date).split("T")[0]

        # collecting video statistics
        video_stats_url = "https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+YOUTUBE_API_KEY
        video_stats_response = requests.get(video_stats_url).json()

        view_count = video_stats_response['items'][0]["statistics"]["viewCount"]
        like_count = video_stats_response['items'][0]["statistics"]["likeCount"]

        #save in pandas df
        df = df._append({
            "video_id": video_id,
            "video_title": video_title,
            "upload_date": upload_date,
            "view_count": view_count,
            "like_count": like_count
        }, 
        ignore_index = True
        )

# %%
video_id = "mZx4DSUzFFQ"
video_url_endpoint = "https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+YOUTUBE_API_KEY
video_response = requests.get(video_url_endpoint).json()

# %%
video_response
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'rTKbZCNYmVpBTgdSuCrY9ro95yk',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'IwHn-XE8GSQGivwAKBFGn7i1k_I',
#    'id': 'mZx4DSUzFFQ',
#    'statistics': {'viewCount': '52982',
#     'likeCount': '1837',
#     'favoriteCount': '0'}}],
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 1}}

# %%
video_response['items'][0]['statistics']
# Out:
# {'viewCount': '52982', 'likeCount': '1837', 'favoriteCount': '0'}

# %% [markdown]
# ##### Creating Workflow

# %%
import requests
import pandas as pd
import time
from config import YOUTUBE_API_KEY

# %%
def get_video_statistics(video_id, youtube_api_key):
    # collecting video statistics
    video_stats_url = "https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+youtube_api_key
    video_stats_response = requests.get(video_stats_url).json()

    view_count = video_stats_response['items'][0]["statistics"]["viewCount"]
    like_count = video_stats_response['items'][0]["statistics"]["likeCount"]

    return view_count, like_count

# %%
def get_videos_from_channel(df, channel_id, youtube_api_key):
    # make API call
    pageToken = ""
    url = "https://www.googleapis.com/youtube/v3/search?key="+youtube_api_key+"&channelId="+channel_id+"&part=snippet,id&order=date&maxResults=1000"+pageToken
    
    response = requests.get(url).json()
    time.sleep(3)

    for video in response['items']:
        if video['id']['kind'] == 'youtube#video':
            video_title = video['snippet']['title']
            video_id = video['id']['videoId']
            upload_date = video['snippet']['publishedAt']
            upload_date= str(upload_date).split("T")[0]

            view_count, like_count = get_video_statistics(video_id, youtube_api_key)

            #save in pandas df
            df = df._append({
                "video_id": video_id,
                "video_title": video_title,
                "upload_date": upload_date,
                "view_count": view_count,
                "like_count": like_count
            }, 
            ignore_index = True
            )
    return df

# %%
CHANNEL_ID = "UC6OI7Crv96jgra5pwJNDFRQ"

df = pd.DataFrame(columns=["video_id","video_title","upload_date","view_count","like_count"]) 
youtube_data = get_videos_from_channel(df, CHANNEL_ID, YOUTUBE_API_KEY)

# %%
youtube_data.head()
# Out:
#       video_id                                        video_title upload_date  \
# 0  SwFG0k9ezHg  Sezen Aksu - Gidiyorum #SezenAksu #MinikSerçe ...  2023-12-03
# 1  EF9NO-fvs3c  Sezen Aksu - Keskin Bıçak #SezenAksu #MinikSer...  2023-11-29
# 2  _y08PXbalHg  Sezen Aksu - Erkek Güzeli #SezenAksu #MinikSer...  2023-11-26
# 3  7HNOJisHhbg     Sezen Aksu - Yanıyom Ölüyom (Canlı Performans)  2023-11-03
# 4  EOADibxhQms  Sezen Aksu - Değer mi? #SezenAksu #MinikSerçe ...  2023-10-28
#
#   view_count like_count
# 0      16245       1104
# 1      14936        879
# 2      24259       1371
# 3     354438       5336
# 4       8291        566

# %%
youtube_data.tail()
# Out:
#        video_id                                        video_title  \
# 45  PrJULYp6XJc  Sezen Aksu - Erkek Güzeli (Lyrics | Şarkı Söz...
# 46  gi4koQNYrGw      Sezen Aksu - Kaderim (Lyrics | Şarkı Sözleri)
# 47  IqkKxPeWBPQ  Sezen Aksu, Kardeş Türküler &amp; Ara Dinkjian...
# 48  KzzIZNQ2bmY      Sezen Aksu - Tutuklu (Lyrics | Şarkı Sözleri)
# 49  eMlIhNIZHio                Sezen Aksu - Affet (Official Video)
#
#    upload_date view_count like_count
# 45  2021-05-13    5826930      28508
# 46  2021-05-04     538634      11443
# 47  2021-04-01     344897       6934
# 48  2021-03-11    1000950      12573
# 49  2021-02-02   18230430     167902
